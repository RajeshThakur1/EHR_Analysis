# %%
import os
import pandas as pd

# %%
df = pd.read_csv("../data/processed/concatenated.csv")

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'DMIndicator', 'RespiratoryRate_Max',
#        'Temperature_Max', 'RespiratoryRate_Min', 'DiastolicBP_Std', 'BMI_Mean',
#        'RespiratoryRate_Mean', 'Temperature_Mean', 'BMI_Change',
#        'DiastolicBP_Change', 'Height_Change', 'RespiratoryRate_Change',
#        'SystolicBP_Change', 'Temperature_Change', 'Weight_Change'],
#       dtype='object')

# %%
df.describe().T
# Out:
#                          count       mean        std        min        25%  \
# Age                     9948.0  54.603940  17.493912  18.000000  42.000000
# Gender                  9948.0   0.426518   0.494596   0.000000   0.000000
# DMIndicator             9948.0   0.191395   0.393419   0.000000   0.000000
# RespiratoryRate_Max     9948.0  18.469371   3.933137  12.000000  16.915026
# Temperature_Max         9948.0  98.400031   1.138347  93.600000  97.765331
# RespiratoryRate_Min     9948.0  15.432859   2.046567   1.000000  14.000000
# DiastolicBP_Std         9948.0   6.204646   2.540097   0.000000   4.478858
# BMI_Mean                9948.0  15.732258   9.703593   0.122124   7.455795
# RespiratoryRate_Mean    9948.0  16.899262   1.097493  11.000000  16.498594
# Temperature_Mean        9948.0  97.751515   0.511149  87.012869  97.710450
# BMI_Change              9948.0   8.979962  12.692927   0.000000   0.000000
# DiastolicBP_Change      9948.0   5.881994   5.896722   0.000000   1.225649
# Height_Change           9948.0   1.083845   1.936504   0.000000   0.000000
# RespiratoryRate_Change  9948.0   0.781747   1.781529   0.000000   0.000000
# SystolicBP_Change       9948.0   9.591503  10.371288   0.000000   2.000000
# Temperature_Change      9948.0   0.358153   0.909684   0.000000   0.000000
# Weight_Change           9948.0  52.398792  78.628487   0.000000   0.500000
#
#                               50%         75%         max
# Age                     55.000000   68.000000   90.000000
# Gender                   0.000000    1.000000    1.000000
# DMIndicator              0.000000    0.000000    1.000000
# RespiratoryRate_Max     16.915026   20.000000   80.000000
# Temperature_Max         98.200000   98.800000  181.000000
# RespiratoryRate_Min     16.000000   16.915026   24.000000
# DiastolicBP_Std          6.153045    7.861375   20.297783
# BMI_Mean                14.613946   22.918650   50.900000
# RespiratoryRate_Mean    16.915026   17.223523   37.000000
# Temperature_Mean        97.765331   97.904545  106.195732
# BMI_Change               0.626000   18.754000   66.483000
# DiastolicBP_Change       4.000000    9.000000   40.000000
# Height_Change            0.000000    1.400409   12.103274
# RespiratoryRate_Change   0.000000    1.000000   61.084974
# SystolicBP_Change        6.728523   14.000000  141.000000
# Temperature_Change       0.100000    0.500000   28.982665
# Weight_Change            4.000000  107.925000  451.948000

# %%
overview = df.describe()
overview.loc[['min','max']].to_json("schema_in.json")

# %%
class NotInRange(Exception):
    def __init__(self, input_, message="value not in range"):
        self.input_ = input_
        self.message = message
        super().__init__

# %%
raise CustomEr
